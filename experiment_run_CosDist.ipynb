# %%
import os
import time

output_directory = "./results_CosDist"
os.makedirs(output_directory, exist_ok=True)
notebook = "PP_steps_verification_CosDist.ipynb"

# %%
dataset_id_list = ['891', '2', '45']

case_id_list = [str(i) for i in range(15)]

repeat = 5

# %%
for rep in range(repeat):
    os.environ['REPEAT'] = str(rep)
    for dataset_id in dataset_id_list:
        os.environ['DATASET_ID'] = dataset_id
        
        if os.environ['DATASET_ID'] == '891':
            epsilon_list = ['1', '5', '10', '50', '100', '0']
            os.environ['NUMERICAL_COLUMNS'] = 'BMI, GenHlth, MentHlth, PhysHlth, Age, Education, Income'
        elif os.environ['DATASET_ID'] == '2':
            epsilon_list = ['1', '5', '10', '50', '100', '0']
            os.environ['NUMERICAL_COLUMNS'] = 'age, fnlwgt, education-num, capital-gain, capital-loss, hours-per-week'
        elif os.environ['DATASET_ID'] == '45':
            epsilon_list = ['1', '5', '10', '50', '100', '0']
            os.environ['NUMERICAL_COLUMNS'] = 'age, trestbps, chol, thalach, oldpeak, ca'
            
        for eps in epsilon_list:
            os.environ['EPSILON'] = eps
            for case_id in case_id_list:
                os.environ['CASE_ID'] = case_id
        
                output_file = os.path.join(output_directory, f"output_notebook_eps{eps}_caseID{case_id}_rep{rep}.ipynb")
                
                command = f"jupyter nbconvert --to notebook --execute {notebook} --output {output_file}"
                # command = f"jupyter nbconvert --to notebook --execute {notebook}"

                os.system(command)
                print(f'rep{rep}_dataset{dataset_id}_eps{eps}_caseID{case_id}')
# Out:
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 185506 bytes to results_CosDist/output_notebook_eps1_caseID0_rep0.ipynb
# rep0_dataset891_eps1_caseID0
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 111250 bytes to results_CosDist/output_notebook_eps1_caseID1_rep0.ipynb
# rep0_dataset891_eps1_caseID1
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 188772 bytes to results_CosDist/output_notebook_eps1_caseID2_rep0.ipynb
# rep0_dataset891_eps1_caseID2
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 187579 bytes to results_CosDist/output_notebook_eps1_caseID3_rep0.ipynb
# rep0_dataset891_eps1_caseID3
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 200254 bytes to results_CosDist/output_notebook_eps1_caseID4_rep0.ipynb
# rep0_dataset891_eps1_caseID4
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 142425 bytes to results_CosDist/output_notebook_eps1_caseID5_rep0.ipynb
# rep0_dataset891_eps1_caseID5
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 179714 bytes to results_CosDist/output_notebook_eps1_caseID6_rep0.ipynb
# rep0_dataset891_eps1_caseID6
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 152890 bytes to results_CosDist/output_notebook_eps1_caseID7_rep0.ipynb
# rep0_dataset891_eps1_caseID7
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 173819 bytes to results_CosDist/output_notebook_eps1_caseID8_rep0.ipynb
# rep0_dataset891_eps1_caseID8
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 194906 bytes to results_CosDist/output_notebook_eps1_caseID9_rep0.ipynb
# rep0_dataset891_eps1_caseID9
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 191921 bytes to results_CosDist/output_notebook_eps1_caseID10_rep0.ipynb
# rep0_dataset891_eps1_caseID10
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 208035 bytes to results_CosDist/output_notebook_eps1_caseID11_rep0.ipynb
# rep0_dataset891_eps1_caseID11
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 153950 bytes to results_CosDist/output_notebook_eps1_caseID12_rep0.ipynb
# rep0_dataset891_eps1_caseID12
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 131174 bytes to results_CosDist/output_notebook_eps1_caseID13_rep0.ipynb
# rep0_dataset891_eps1_caseID13
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 127743 bytes to results_CosDist/output_notebook_eps1_caseID14_rep0.ipynb
# rep0_dataset891_eps1_caseID14
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 171068 bytes to results_CosDist/output_notebook_eps5_caseID0_rep0.ipynb
# rep0_dataset891_eps5_caseID0
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 204706 bytes to results_CosDist/output_notebook_eps5_caseID1_rep0.ipynb
# rep0_dataset891_eps5_caseID1
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 159891 bytes to results_CosDist/output_notebook_eps5_caseID2_rep0.ipynb
# rep0_dataset891_eps5_caseID2
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 191803 bytes to results_CosDist/output_notebook_eps5_caseID3_rep0.ipynb
# rep0_dataset891_eps5_caseID3
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 152701 bytes to results_CosDist/output_notebook_eps5_caseID4_rep0.ipynb
# rep0_dataset891_eps5_caseID4
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 182713 bytes to results_CosDist/output_notebook_eps5_caseID5_rep0.ipynb
# rep0_dataset891_eps5_caseID5
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 198414 bytes to results_CosDist/output_notebook_eps5_caseID6_rep0.ipynb
# rep0_dataset891_eps5_caseID6
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 148399 bytes to results_CosDist/output_notebook_eps5_caseID7_rep0.ipynb
# rep0_dataset891_eps5_caseID7
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 175226 bytes to results_CosDist/output_notebook_eps5_caseID8_rep0.ipynb
# rep0_dataset891_eps5_caseID8
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 148513 bytes to results_CosDist/output_notebook_eps5_caseID9_rep0.ipynb
# rep0_dataset891_eps5_caseID9
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 146970 bytes to results_CosDist/output_notebook_eps5_caseID10_rep0.ipynb
# rep0_dataset891_eps5_caseID10
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 182741 bytes to results_CosDist/output_notebook_eps5_caseID11_rep0.ipynb
# rep0_dataset891_eps5_caseID11
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 194280 bytes to results_CosDist/output_notebook_eps5_caseID12_rep0.ipynb
# rep0_dataset891_eps5_caseID12
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 188856 bytes to results_CosDist/output_notebook_eps5_caseID13_rep0.ipynb
# rep0_dataset891_eps5_caseID13
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 194626 bytes to results_CosDist/output_notebook_eps5_caseID14_rep0.ipynb
# rep0_dataset891_eps5_caseID14
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 163244 bytes to results_CosDist/output_notebook_eps10_caseID0_rep0.ipynb
# rep0_dataset891_eps10_caseID0
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 187233 bytes to results_CosDist/output_notebook_eps10_caseID1_rep0.ipynb
# rep0_dataset891_eps10_caseID1
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 199831 bytes to results_CosDist/output_notebook_eps10_caseID2_rep0.ipynb
# rep0_dataset891_eps10_caseID2
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 193110 bytes to results_CosDist/output_notebook_eps10_caseID3_rep0.ipynb
# rep0_dataset891_eps10_caseID3
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 186557 bytes to results_CosDist/output_notebook_eps10_caseID4_rep0.ipynb
# rep0_dataset891_eps10_caseID4
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 184457 bytes to results_CosDist/output_notebook_eps10_caseID5_rep0.ipynb
# rep0_dataset891_eps10_caseID5
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 164172 bytes to results_CosDist/output_notebook_eps10_caseID6_rep0.ipynb
# rep0_dataset891_eps10_caseID6
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 181609 bytes to results_CosDist/output_notebook_eps10_caseID7_rep0.ipynb
# rep0_dataset891_eps10_caseID7
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 171804 bytes to results_CosDist/output_notebook_eps10_caseID8_rep0.ipynb
# rep0_dataset891_eps10_caseID8
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 90985 bytes to results_CosDist/output_notebook_eps10_caseID9_rep0.ipynb
# rep0_dataset891_eps10_caseID9
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 153413 bytes to results_CosDist/output_notebook_eps10_caseID10_rep0.ipynb
# rep0_dataset891_eps10_caseID10
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 188941 bytes to results_CosDist/output_notebook_eps10_caseID11_rep0.ipynb
# rep0_dataset891_eps10_caseID11
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 219196 bytes to results_CosDist/output_notebook_eps10_caseID12_rep0.ipynb
# rep0_dataset891_eps10_caseID12
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 162754 bytes to results_CosDist/output_notebook_eps10_caseID13_rep0.ipynb
# rep0_dataset891_eps10_caseID13
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 204628 bytes to results_CosDist/output_notebook_eps10_caseID14_rep0.ipynb
# rep0_dataset891_eps10_caseID14
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 146788 bytes to results_CosDist/output_notebook_eps50_caseID0_rep0.ipynb
# rep0_dataset891_eps50_caseID0
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 183329 bytes to results_CosDist/output_notebook_eps50_caseID1_rep0.ipynb
# rep0_dataset891_eps50_caseID1
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 170077 bytes to results_CosDist/output_notebook_eps50_caseID2_rep0.ipynb
# rep0_dataset891_eps50_caseID2
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 183564 bytes to results_CosDist/output_notebook_eps50_caseID3_rep0.ipynb
# rep0_dataset891_eps50_caseID3
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 187249 bytes to results_CosDist/output_notebook_eps50_caseID4_rep0.ipynb
# rep0_dataset891_eps50_caseID4
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 204320 bytes to results_CosDist/output_notebook_eps50_caseID5_rep0.ipynb
# rep0_dataset891_eps50_caseID5
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 158885 bytes to results_CosDist/output_notebook_eps50_caseID6_rep0.ipynb
# rep0_dataset891_eps50_caseID6
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 194768 bytes to results_CosDist/output_notebook_eps50_caseID7_rep0.ipynb
# rep0_dataset891_eps50_caseID7
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 220776 bytes to results_CosDist/output_notebook_eps50_caseID8_rep0.ipynb
# rep0_dataset891_eps50_caseID8
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 137786 bytes to results_CosDist/output_notebook_eps50_caseID9_rep0.ipynb
# rep0_dataset891_eps50_caseID9
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 188028 bytes to results_CosDist/output_notebook_eps50_caseID10_rep0.ipynb
# rep0_dataset891_eps50_caseID10
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 181791 bytes to results_CosDist/output_notebook_eps50_caseID11_rep0.ipynb
# rep0_dataset891_eps50_caseID11
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 195487 bytes to results_CosDist/output_notebook_eps50_caseID12_rep0.ipynb
# rep0_dataset891_eps50_caseID12
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 191930 bytes to results_CosDist/output_notebook_eps50_caseID13_rep0.ipynb
# rep0_dataset891_eps50_caseID13
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 178676 bytes to results_CosDist/output_notebook_eps50_caseID14_rep0.ipynb
# rep0_dataset891_eps50_caseID14
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 142466 bytes to results_CosDist/output_notebook_eps100_caseID0_rep0.ipynb
# rep0_dataset891_eps100_caseID0
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 185148 bytes to results_CosDist/output_notebook_eps100_caseID1_rep0.ipynb
# rep0_dataset891_eps100_caseID1
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 192049 bytes to results_CosDist/output_notebook_eps100_caseID2_rep0.ipynb
# rep0_dataset891_eps100_caseID2
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 150237 bytes to results_CosDist/output_notebook_eps100_caseID3_rep0.ipynb
# rep0_dataset891_eps100_caseID3
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 182027 bytes to results_CosDist/output_notebook_eps100_caseID4_rep0.ipynb
# rep0_dataset891_eps100_caseID4
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 183871 bytes to results_CosDist/output_notebook_eps100_caseID5_rep0.ipynb
# rep0_dataset891_eps100_caseID5
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 208751 bytes to results_CosDist/output_notebook_eps100_caseID6_rep0.ipynb
# rep0_dataset891_eps100_caseID6
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 198814 bytes to results_CosDist/output_notebook_eps100_caseID7_rep0.ipynb
# rep0_dataset891_eps100_caseID7
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 209284 bytes to results_CosDist/output_notebook_eps100_caseID8_rep0.ipynb
# rep0_dataset891_eps100_caseID8
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 154462 bytes to results_CosDist/output_notebook_eps100_caseID9_rep0.ipynb
# rep0_dataset891_eps100_caseID9
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 201164 bytes to results_CosDist/output_notebook_eps100_caseID10_rep0.ipynb
# rep0_dataset891_eps100_caseID10
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 182432 bytes to results_CosDist/output_notebook_eps100_caseID11_rep0.ipynb
# rep0_dataset891_eps100_caseID11
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 201902 bytes to results_CosDist/output_notebook_eps100_caseID12_rep0.ipynb
# rep0_dataset891_eps100_caseID12
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 201806 bytes to results_CosDist/output_notebook_eps100_caseID13_rep0.ipynb
# rep0_dataset891_eps100_caseID13
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 203232 bytes to results_CosDist/output_notebook_eps100_caseID14_rep0.ipynb
# rep0_dataset891_eps100_caseID14
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 211201 bytes to results_CosDist/output_notebook_eps0_caseID0_rep0.ipynb
# rep0_dataset891_eps0_caseID0
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 193350 bytes to results_CosDist/output_notebook_eps0_caseID1_rep0.ipynb
# rep0_dataset891_eps0_caseID1
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 159570 bytes to results_CosDist/output_notebook_eps0_caseID2_rep0.ipynb
# rep0_dataset891_eps0_caseID2
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 202074 bytes to results_CosDist/output_notebook_eps0_caseID3_rep0.ipynb
# rep0_dataset891_eps0_caseID3
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 207253 bytes to results_CosDist/output_notebook_eps0_caseID4_rep0.ipynb
# rep0_dataset891_eps0_caseID4
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 204429 bytes to results_CosDist/output_notebook_eps0_caseID5_rep0.ipynb
# rep0_dataset891_eps0_caseID5
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 187524 bytes to results_CosDist/output_notebook_eps0_caseID6_rep0.ipynb
# rep0_dataset891_eps0_caseID6
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 203660 bytes to results_CosDist/output_notebook_eps0_caseID7_rep0.ipynb
# rep0_dataset891_eps0_caseID7
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 190029 bytes to results_CosDist/output_notebook_eps0_caseID8_rep0.ipynb
# rep0_dataset891_eps0_caseID8
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 166809 bytes to results_CosDist/output_notebook_eps0_caseID9_rep0.ipynb
# rep0_dataset891_eps0_caseID9
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 166658 bytes to results_CosDist/output_notebook_eps0_caseID10_rep0.ipynb
# rep0_dataset891_eps0_caseID10
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 152864 bytes to results_CosDist/output_notebook_eps0_caseID11_rep0.ipynb
# rep0_dataset891_eps0_caseID11
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 149169 bytes to results_CosDist/output_notebook_eps0_caseID12_rep0.ipynb
# rep0_dataset891_eps0_caseID12
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 179234 bytes to results_CosDist/output_notebook_eps0_caseID13_rep0.ipynb
# rep0_dataset891_eps0_caseID13
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 157097 bytes to results_CosDist/output_notebook_eps0_caseID14_rep0.ipynb
# rep0_dataset891_eps0_caseID14
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 115537 bytes to results_CosDist/output_notebook_eps1_caseID0_rep0.ipynb
# rep0_dataset2_eps1_caseID0
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 102924 bytes to results_CosDist/output_notebook_eps1_caseID1_rep0.ipynb
# rep0_dataset2_eps1_caseID1
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 122705 bytes to results_CosDist/output_notebook_eps1_caseID2_rep0.ipynb
# rep0_dataset2_eps1_caseID2
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# ...
# rep4_dataset45_eps50_caseID13
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 24382 bytes to results_CosDist/output_notebook_eps50_caseID14_rep4.ipynb
# rep4_dataset45_eps50_caseID14
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 24094 bytes to results_CosDist/output_notebook_eps100_caseID0_rep4.ipynb
# rep4_dataset45_eps100_caseID0
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 23837 bytes to results_CosDist/output_notebook_eps100_caseID1_rep4.ipynb
# rep4_dataset45_eps100_caseID1
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 24723 bytes to results_CosDist/output_notebook_eps100_caseID2_rep4.ipynb
# rep4_dataset45_eps100_caseID2
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 24041 bytes to results_CosDist/output_notebook_eps100_caseID3_rep4.ipynb
# rep4_dataset45_eps100_caseID3
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 24441 bytes to results_CosDist/output_notebook_eps100_caseID4_rep4.ipynb
# rep4_dataset45_eps100_caseID4
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 24740 bytes to results_CosDist/output_notebook_eps100_caseID5_rep4.ipynb
# rep4_dataset45_eps100_caseID5
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 23903 bytes to results_CosDist/output_notebook_eps100_caseID6_rep4.ipynb
# rep4_dataset45_eps100_caseID6
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 24458 bytes to results_CosDist/output_notebook_eps100_caseID7_rep4.ipynb
# rep4_dataset45_eps100_caseID7
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 23716 bytes to results_CosDist/output_notebook_eps100_caseID8_rep4.ipynb
# rep4_dataset45_eps100_caseID8
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 24362 bytes to results_CosDist/output_notebook_eps100_caseID9_rep4.ipynb
# rep4_dataset45_eps100_caseID9
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 23910 bytes to results_CosDist/output_notebook_eps100_caseID10_rep4.ipynb
# rep4_dataset45_eps100_caseID10
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 24249 bytes to results_CosDist/output_notebook_eps100_caseID11_rep4.ipynb
# rep4_dataset45_eps100_caseID11
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 24351 bytes to results_CosDist/output_notebook_eps100_caseID12_rep4.ipynb
# rep4_dataset45_eps100_caseID12
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 23582 bytes to results_CosDist/output_notebook_eps100_caseID13_rep4.ipynb
# rep4_dataset45_eps100_caseID13
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 24397 bytes to results_CosDist/output_notebook_eps100_caseID14_rep4.ipynb
# rep4_dataset45_eps100_caseID14
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 24220 bytes to results_CosDist/output_notebook_eps0_caseID0_rep4.ipynb
# rep4_dataset45_eps0_caseID0
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 23995 bytes to results_CosDist/output_notebook_eps0_caseID1_rep4.ipynb
# rep4_dataset45_eps0_caseID1
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 24979 bytes to results_CosDist/output_notebook_eps0_caseID2_rep4.ipynb
# rep4_dataset45_eps0_caseID2
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 24113 bytes to results_CosDist/output_notebook_eps0_caseID3_rep4.ipynb
# rep4_dataset45_eps0_caseID3
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 23846 bytes to results_CosDist/output_notebook_eps0_caseID4_rep4.ipynb
# rep4_dataset45_eps0_caseID4
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 24413 bytes to results_CosDist/output_notebook_eps0_caseID5_rep4.ipynb
# rep4_dataset45_eps0_caseID5
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 23801 bytes to results_CosDist/output_notebook_eps0_caseID6_rep4.ipynb
# rep4_dataset45_eps0_caseID6
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 24444 bytes to results_CosDist/output_notebook_eps0_caseID7_rep4.ipynb
# rep4_dataset45_eps0_caseID7
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 23777 bytes to results_CosDist/output_notebook_eps0_caseID8_rep4.ipynb
# rep4_dataset45_eps0_caseID8
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 24450 bytes to results_CosDist/output_notebook_eps0_caseID9_rep4.ipynb
# rep4_dataset45_eps0_caseID9
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 23652 bytes to results_CosDist/output_notebook_eps0_caseID10_rep4.ipynb
# rep4_dataset45_eps0_caseID10
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 24249 bytes to results_CosDist/output_notebook_eps0_caseID11_rep4.ipynb
# rep4_dataset45_eps0_caseID11
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 24351 bytes to results_CosDist/output_notebook_eps0_caseID12_rep4.ipynb
# rep4_dataset45_eps0_caseID12
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 23427 bytes to results_CosDist/output_notebook_eps0_caseID13_rep4.ipynb
# rep4_dataset45_eps0_caseID13
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# rep4_dataset45_eps0_caseID14
# [NbConvertApp] Writing 24313 bytes to results_CosDist/output_notebook_eps0_caseID14_rep4.ipynb
