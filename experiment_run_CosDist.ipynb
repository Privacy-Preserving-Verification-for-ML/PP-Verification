# %%
import os
import time

output_directory = "./results_CosDist"
os.makedirs(output_directory, exist_ok=True)
notebook = "PP_steps_verification_CosDist.ipynb"

# %%
dataset_id_list = ['891', '2', '697']

case_id_list = [str(i) for i in range(15)]

repeat = 5

# %%
for rep in range(repeat):
    os.environ['REPEAT'] = str(rep)
    for dataset_id in dataset_id_list:
        os.environ['DATASET_ID'] = dataset_id
        
        if os.environ['DATASET_ID'] == '891':
            epsilon_list = ['0.1', '1', '10', '100', '1000', '0']
            os.environ['NUMERICAL_COLUMNS'] = 'BMI, GenHlth, MentHlth, PhysHlth, Age, Education, Income'
        elif os.environ['DATASET_ID'] == '2':
            epsilon_list = ['0.1', '1', '10', '100', '1000', '0']
            os.environ['NUMERICAL_COLUMNS'] = 'age, fnlwgt, education-num, capital-gain, capital-loss, hours-per-week'
        elif os.environ['DATASET_ID'] == '697':
            epsilon_list = ['0.1', '1', '10', '100', '1000', '0']
            os.environ['NUMERICAL_COLUMNS'] = 'Previous qualification (grade), Admission grade, Unemployment rate, Inflation rate, GDP'

            
        for eps in epsilon_list:
            os.environ['EPSILON'] = eps
            for case_id in case_id_list:
                os.environ['CASE_ID'] = case_id
        
                output_file = os.path.join(output_directory, f"output_notebook_eps{eps}_caseID{case_id}_rep{rep}.ipynb")
                
                command = f"jupyter nbconvert --to notebook --execute {notebook} --output {output_file}"
                # command = f"jupyter nbconvert --to notebook --execute {notebook}"

                os.system(command)
                print(f'rep{rep}_dataset{dataset_id}_eps{eps}_caseID{case_id}')
# Out:
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 463856 bytes to results_CosDist/output_notebook_eps0.1_caseID0_rep0.ipynb
# rep0_dataset891_eps0.1_caseID0
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 483634 bytes to results_CosDist/output_notebook_eps0.1_caseID1_rep0.ipynb
# rep0_dataset891_eps0.1_caseID1
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 483157 bytes to results_CosDist/output_notebook_eps0.1_caseID2_rep0.ipynb
# rep0_dataset891_eps0.1_caseID2
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 470399 bytes to results_CosDist/output_notebook_eps0.1_caseID3_rep0.ipynb
# rep0_dataset891_eps0.1_caseID3
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 456388 bytes to results_CosDist/output_notebook_eps0.1_caseID4_rep0.ipynb
# rep0_dataset891_eps0.1_caseID4
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 486392 bytes to results_CosDist/output_notebook_eps0.1_caseID5_rep0.ipynb
# rep0_dataset891_eps0.1_caseID5
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 492437 bytes to results_CosDist/output_notebook_eps0.1_caseID6_rep0.ipynb
# rep0_dataset891_eps0.1_caseID6
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 487139 bytes to results_CosDist/output_notebook_eps0.1_caseID7_rep0.ipynb
# rep0_dataset891_eps0.1_caseID7
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 484536 bytes to results_CosDist/output_notebook_eps0.1_caseID8_rep0.ipynb
# rep0_dataset891_eps0.1_caseID8
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 478273 bytes to results_CosDist/output_notebook_eps0.1_caseID9_rep0.ipynb
# rep0_dataset891_eps0.1_caseID9
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 468565 bytes to results_CosDist/output_notebook_eps0.1_caseID10_rep0.ipynb
# rep0_dataset891_eps0.1_caseID10
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 488599 bytes to results_CosDist/output_notebook_eps0.1_caseID11_rep0.ipynb
# rep0_dataset891_eps0.1_caseID11
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 490500 bytes to results_CosDist/output_notebook_eps0.1_caseID12_rep0.ipynb
# rep0_dataset891_eps0.1_caseID12
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 482247 bytes to results_CosDist/output_notebook_eps0.1_caseID13_rep0.ipynb
# rep0_dataset891_eps0.1_caseID13
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 480402 bytes to results_CosDist/output_notebook_eps0.1_caseID14_rep0.ipynb
# rep0_dataset891_eps0.1_caseID14
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 476546 bytes to results_CosDist/output_notebook_eps1_caseID0_rep0.ipynb
# rep0_dataset891_eps1_caseID0
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 493122 bytes to results_CosDist/output_notebook_eps1_caseID1_rep0.ipynb
# rep0_dataset891_eps1_caseID1
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 491358 bytes to results_CosDist/output_notebook_eps1_caseID2_rep0.ipynb
# rep0_dataset891_eps1_caseID2
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 478605 bytes to results_CosDist/output_notebook_eps1_caseID3_rep0.ipynb
# rep0_dataset891_eps1_caseID3
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 483561 bytes to results_CosDist/output_notebook_eps1_caseID4_rep0.ipynb
# rep0_dataset891_eps1_caseID4
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 494261 bytes to results_CosDist/output_notebook_eps1_caseID5_rep0.ipynb
# rep0_dataset891_eps1_caseID5
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 493561 bytes to results_CosDist/output_notebook_eps1_caseID6_rep0.ipynb
# rep0_dataset891_eps1_caseID6
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 491154 bytes to results_CosDist/output_notebook_eps1_caseID7_rep0.ipynb
# rep0_dataset891_eps1_caseID7
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 491769 bytes to results_CosDist/output_notebook_eps1_caseID8_rep0.ipynb
# rep0_dataset891_eps1_caseID8
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 492583 bytes to results_CosDist/output_notebook_eps1_caseID9_rep0.ipynb
# rep0_dataset891_eps1_caseID9
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 470177 bytes to results_CosDist/output_notebook_eps1_caseID10_rep0.ipynb
# rep0_dataset891_eps1_caseID10
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 493581 bytes to results_CosDist/output_notebook_eps1_caseID11_rep0.ipynb
# rep0_dataset891_eps1_caseID11
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 496284 bytes to results_CosDist/output_notebook_eps1_caseID12_rep0.ipynb
# rep0_dataset891_eps1_caseID12
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 493823 bytes to results_CosDist/output_notebook_eps1_caseID13_rep0.ipynb
# rep0_dataset891_eps1_caseID13
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 494221 bytes to results_CosDist/output_notebook_eps1_caseID14_rep0.ipynb
# rep0_dataset891_eps1_caseID14
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 471734 bytes to results_CosDist/output_notebook_eps10_caseID0_rep0.ipynb
# rep0_dataset891_eps10_caseID0
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 493125 bytes to results_CosDist/output_notebook_eps10_caseID1_rep0.ipynb
# rep0_dataset891_eps10_caseID1
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 491848 bytes to results_CosDist/output_notebook_eps10_caseID2_rep0.ipynb
# rep0_dataset891_eps10_caseID2
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 475875 bytes to results_CosDist/output_notebook_eps10_caseID3_rep0.ipynb
# rep0_dataset891_eps10_caseID3
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 469101 bytes to results_CosDist/output_notebook_eps10_caseID4_rep0.ipynb
# rep0_dataset891_eps10_caseID4
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 495719 bytes to results_CosDist/output_notebook_eps10_caseID5_rep0.ipynb
# rep0_dataset891_eps10_caseID5
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 491961 bytes to results_CosDist/output_notebook_eps10_caseID6_rep0.ipynb
# rep0_dataset891_eps10_caseID6
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 496144 bytes to results_CosDist/output_notebook_eps10_caseID7_rep0.ipynb
# rep0_dataset891_eps10_caseID7
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 487115 bytes to results_CosDist/output_notebook_eps10_caseID8_rep0.ipynb
# rep0_dataset891_eps10_caseID8
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 488567 bytes to results_CosDist/output_notebook_eps10_caseID9_rep0.ipynb
# rep0_dataset891_eps10_caseID9
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 483695 bytes to results_CosDist/output_notebook_eps10_caseID10_rep0.ipynb
# rep0_dataset891_eps10_caseID10
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 493747 bytes to results_CosDist/output_notebook_eps10_caseID11_rep0.ipynb
# rep0_dataset891_eps10_caseID11
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 493724 bytes to results_CosDist/output_notebook_eps10_caseID12_rep0.ipynb
# rep0_dataset891_eps10_caseID12
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 488682 bytes to results_CosDist/output_notebook_eps10_caseID13_rep0.ipynb
# rep0_dataset891_eps10_caseID13
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 489887 bytes to results_CosDist/output_notebook_eps10_caseID14_rep0.ipynb
# rep0_dataset891_eps10_caseID14
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 463696 bytes to results_CosDist/output_notebook_eps100_caseID0_rep0.ipynb
# rep0_dataset891_eps100_caseID0
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 488311 bytes to results_CosDist/output_notebook_eps100_caseID1_rep0.ipynb
# rep0_dataset891_eps100_caseID1
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 487672 bytes to results_CosDist/output_notebook_eps100_caseID2_rep0.ipynb
# rep0_dataset891_eps100_caseID2
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 490827 bytes to results_CosDist/output_notebook_eps100_caseID3_rep0.ipynb
# rep0_dataset891_eps100_caseID3
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 472154 bytes to results_CosDist/output_notebook_eps100_caseID4_rep0.ipynb
# rep0_dataset891_eps100_caseID4
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 489452 bytes to results_CosDist/output_notebook_eps100_caseID5_rep0.ipynb
# rep0_dataset891_eps100_caseID5
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 488270 bytes to results_CosDist/output_notebook_eps100_caseID6_rep0.ipynb
# rep0_dataset891_eps100_caseID6
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 486346 bytes to results_CosDist/output_notebook_eps100_caseID7_rep0.ipynb
# rep0_dataset891_eps100_caseID7
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 486314 bytes to results_CosDist/output_notebook_eps100_caseID8_rep0.ipynb
# rep0_dataset891_eps100_caseID8
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 490660 bytes to results_CosDist/output_notebook_eps100_caseID9_rep0.ipynb
# rep0_dataset891_eps100_caseID9
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 481285 bytes to results_CosDist/output_notebook_eps100_caseID10_rep0.ipynb
# rep0_dataset891_eps100_caseID10
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 488606 bytes to results_CosDist/output_notebook_eps100_caseID11_rep0.ipynb
# rep0_dataset891_eps100_caseID11
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 488579 bytes to results_CosDist/output_notebook_eps100_caseID12_rep0.ipynb
# rep0_dataset891_eps100_caseID12
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 474854 bytes to results_CosDist/output_notebook_eps100_caseID13_rep0.ipynb
# rep0_dataset891_eps100_caseID13
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 484424 bytes to results_CosDist/output_notebook_eps100_caseID14_rep0.ipynb
# rep0_dataset891_eps100_caseID14
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 460966 bytes to results_CosDist/output_notebook_eps1000_caseID0_rep0.ipynb
# rep0_dataset891_eps1000_caseID0
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 485410 bytes to results_CosDist/output_notebook_eps1000_caseID1_rep0.ipynb
# rep0_dataset891_eps1000_caseID1
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 486222 bytes to results_CosDist/output_notebook_eps1000_caseID2_rep0.ipynb
# rep0_dataset891_eps1000_caseID2
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 463495 bytes to results_CosDist/output_notebook_eps1000_caseID3_rep0.ipynb
# rep0_dataset891_eps1000_caseID3
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 470060 bytes to results_CosDist/output_notebook_eps1000_caseID4_rep0.ipynb
# rep0_dataset891_eps1000_caseID4
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 484947 bytes to results_CosDist/output_notebook_eps1000_caseID5_rep0.ipynb
# rep0_dataset891_eps1000_caseID5
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 483124 bytes to results_CosDist/output_notebook_eps1000_caseID6_rep0.ipynb
# rep0_dataset891_eps1000_caseID6
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 485374 bytes to results_CosDist/output_notebook_eps1000_caseID7_rep0.ipynb
# rep0_dataset891_eps1000_caseID7
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 478760 bytes to results_CosDist/output_notebook_eps1000_caseID8_rep0.ipynb
# rep0_dataset891_eps1000_caseID8
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 485679 bytes to results_CosDist/output_notebook_eps1000_caseID9_rep0.ipynb
# rep0_dataset891_eps1000_caseID9
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 469537 bytes to results_CosDist/output_notebook_eps1000_caseID10_rep0.ipynb
# rep0_dataset891_eps1000_caseID10
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 491982 bytes to results_CosDist/output_notebook_eps1000_caseID11_rep0.ipynb
# rep0_dataset891_eps1000_caseID11
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 489864 bytes to results_CosDist/output_notebook_eps1000_caseID12_rep0.ipynb
# rep0_dataset891_eps1000_caseID12
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 475822 bytes to results_CosDist/output_notebook_eps1000_caseID13_rep0.ipynb
# rep0_dataset891_eps1000_caseID13
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 485388 bytes to results_CosDist/output_notebook_eps1000_caseID14_rep0.ipynb
# rep0_dataset891_eps1000_caseID14
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 432820 bytes to results_CosDist/output_notebook_eps0_caseID0_rep0.ipynb
# rep0_dataset891_eps0_caseID0
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 464033 bytes to results_CosDist/output_notebook_eps0_caseID1_rep0.ipynb
# rep0_dataset891_eps0_caseID1
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 472396 bytes to results_CosDist/output_notebook_eps0_caseID2_rep0.ipynb
# rep0_dataset891_eps0_caseID2
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 432304 bytes to results_CosDist/output_notebook_eps0_caseID3_rep0.ipynb
# rep0_dataset891_eps0_caseID3
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 449966 bytes to results_CosDist/output_notebook_eps0_caseID4_rep0.ipynb
# rep0_dataset891_eps0_caseID4
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 481574 bytes to results_CosDist/output_notebook_eps0_caseID5_rep0.ipynb
# rep0_dataset891_eps0_caseID5
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 472353 bytes to results_CosDist/output_notebook_eps0_caseID6_rep0.ipynb
# rep0_dataset891_eps0_caseID6
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 484736 bytes to results_CosDist/output_notebook_eps0_caseID7_rep0.ipynb
# rep0_dataset891_eps0_caseID7
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 470230 bytes to results_CosDist/output_notebook_eps0_caseID8_rep0.ipynb
# rep0_dataset891_eps0_caseID8
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 466060 bytes to results_CosDist/output_notebook_eps0_caseID9_rep0.ipynb
# rep0_dataset891_eps0_caseID9
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 436025 bytes to results_CosDist/output_notebook_eps0_caseID10_rep0.ipynb
# rep0_dataset891_eps0_caseID10
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 480732 bytes to results_CosDist/output_notebook_eps0_caseID11_rep0.ipynb
# rep0_dataset891_eps0_caseID11
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 473303 bytes to results_CosDist/output_notebook_eps0_caseID12_rep0.ipynb
# rep0_dataset891_eps0_caseID12
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 501837 bytes to results_CosDist/output_notebook_eps0_caseID13_rep0.ipynb
# rep0_dataset891_eps0_caseID13
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 481203 bytes to results_CosDist/output_notebook_eps0_caseID14_rep0.ipynb
# rep0_dataset891_eps0_caseID14
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 342434 bytes to results_CosDist/output_notebook_eps0.1_caseID0_rep0.ipynb
# rep0_dataset2_eps0.1_caseID0
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 341663 bytes to results_CosDist/output_notebook_eps0.1_caseID1_rep0.ipynb
# rep0_dataset2_eps0.1_caseID1
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 339741 bytes to results_CosDist/output_notebook_eps0.1_caseID2_rep0.ipynb
# ...
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 161518 bytes to results_CosDist/output_notebook_eps100_caseID14_rep4.ipynb
# rep4_dataset697_eps100_caseID14
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 163127 bytes to results_CosDist/output_notebook_eps1000_caseID0_rep4.ipynb
# rep4_dataset697_eps1000_caseID0
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 163620 bytes to results_CosDist/output_notebook_eps1000_caseID1_rep4.ipynb
# rep4_dataset697_eps1000_caseID1
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 161864 bytes to results_CosDist/output_notebook_eps1000_caseID2_rep4.ipynb
# rep4_dataset697_eps1000_caseID2
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 163403 bytes to results_CosDist/output_notebook_eps1000_caseID3_rep4.ipynb
# rep4_dataset697_eps1000_caseID3
# [NbConvertApp] Converting notebook PP_steps_verification_CosDist.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 