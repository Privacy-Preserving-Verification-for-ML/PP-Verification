# %%
import os
import time

output_directory = "./results_Exp"
os.makedirs(output_directory, exist_ok=True)
notebook = "PP_steps_verification_Exp.ipynb"

# %%
dataset_id_list = ['891', '2', '45']

case_id_list = [str(i) for i in range(15)]

repeat = 5

# %%
for rep in range(repeat):
    os.environ['REPEAT'] = str(rep)
    for dataset_id in dataset_id_list:
        os.environ['DATASET_ID'] = dataset_id
        
        if os.environ['DATASET_ID'] == '891':
            epsilon_list = ['1', '5', '10', '50', '100', '0']
            os.environ['NUMERICAL_COLUMNS'] = 'BMI, GenHlth, MentHlth, PhysHlth, Age, Education, Income'
        elif os.environ['DATASET_ID'] == '2':
            epsilon_list = ['1', '5', '10', '50', '100', '0']
            os.environ['NUMERICAL_COLUMNS'] = 'age, fnlwgt, education-num, capital-gain, capital-loss, hours-per-week'
        elif os.environ['DATASET_ID'] == '45':
            epsilon_list = ['1', '5', '10', '50', '100', '0']
            os.environ['NUMERICAL_COLUMNS'] = 'age, trestbps, chol, thalach, oldpeak, ca'
    
        for eps in epsilon_list:
            os.environ['EPSILON'] = eps
            for case_id in case_id_list:
                os.environ['CASE_ID'] = case_id
        
                output_file = os.path.join(output_directory, f"output_notebook_eps{eps}_caseID{case_id}_rep{rep}.ipynb")
                
                command = f"jupyter nbconvert --to notebook --execute {notebook} --output {output_file}"
                # command = f"jupyter nbconvert --to notebook --execute {notebook}"

                os.system(command)
                print(f'rep{rep}_dataset{dataset_id}_eps{eps}_caseID{case_id}')
# Out:
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 156413 bytes to results_Exp/output_notebook_eps1_caseID0_rep0.ipynb
# rep0_dataset891_eps1_caseID0
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 106508 bytes to results_Exp/output_notebook_eps1_caseID1_rep0.ipynb
# rep0_dataset891_eps1_caseID1
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 158733 bytes to results_Exp/output_notebook_eps1_caseID2_rep0.ipynb
# rep0_dataset891_eps1_caseID2
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 105671 bytes to results_Exp/output_notebook_eps1_caseID3_rep0.ipynb
# rep0_dataset891_eps1_caseID3
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 119869 bytes to results_Exp/output_notebook_eps1_caseID4_rep0.ipynb
# rep0_dataset891_eps1_caseID4
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 158361 bytes to results_Exp/output_notebook_eps1_caseID5_rep0.ipynb
# rep0_dataset891_eps1_caseID5
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 137701 bytes to results_Exp/output_notebook_eps1_caseID6_rep0.ipynb
# rep0_dataset891_eps1_caseID6
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 158550 bytes to results_Exp/output_notebook_eps1_caseID7_rep0.ipynb
# rep0_dataset891_eps1_caseID7
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 77558 bytes to results_Exp/output_notebook_eps1_caseID8_rep0.ipynb
# rep0_dataset891_eps1_caseID8
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 107341 bytes to results_Exp/output_notebook_eps1_caseID9_rep0.ipynb
# rep0_dataset891_eps1_caseID9
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 149091 bytes to results_Exp/output_notebook_eps1_caseID10_rep0.ipynb
# rep0_dataset891_eps1_caseID10
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 159295 bytes to results_Exp/output_notebook_eps1_caseID11_rep0.ipynb
# rep0_dataset891_eps1_caseID11
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 109776 bytes to results_Exp/output_notebook_eps1_caseID12_rep0.ipynb
# rep0_dataset891_eps1_caseID12
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 131854 bytes to results_Exp/output_notebook_eps1_caseID13_rep0.ipynb
# rep0_dataset891_eps1_caseID13
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 157577 bytes to results_Exp/output_notebook_eps1_caseID14_rep0.ipynb
# rep0_dataset891_eps1_caseID14
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 127807 bytes to results_Exp/output_notebook_eps10_caseID13_rep0.ipynb
# rep0_dataset891_eps10_caseID13
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 132807 bytes to results_Exp/output_notebook_eps10_caseID14_rep0.ipynb
# rep0_dataset891_eps10_caseID14
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 165114 bytes to results_Exp/output_notebook_eps50_caseID0_rep0.ipynb
# rep0_dataset891_eps50_caseID0
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 107282 bytes to results_Exp/output_notebook_eps50_caseID1_rep0.ipynb
# rep0_dataset891_eps50_caseID1
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 84478 bytes to results_Exp/output_notebook_eps50_caseID2_rep0.ipynb
# rep0_dataset891_eps50_caseID2
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 157829 bytes to results_Exp/output_notebook_eps50_caseID3_rep0.ipynb
# rep0_dataset891_eps50_caseID3
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 155685 bytes to results_Exp/output_notebook_eps50_caseID4_rep0.ipynb
# rep0_dataset891_eps50_caseID4
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 108352 bytes to results_Exp/output_notebook_eps50_caseID5_rep0.ipynb
# rep0_dataset891_eps50_caseID5
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 102956 bytes to results_Exp/output_notebook_eps50_caseID6_rep0.ipynb
# rep0_dataset891_eps50_caseID6
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 106865 bytes to results_Exp/output_notebook_eps50_caseID7_rep0.ipynb
# rep0_dataset891_eps50_caseID7
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 137930 bytes to results_Exp/output_notebook_eps50_caseID8_rep0.ipynb
# rep0_dataset891_eps50_caseID8
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 158953 bytes to results_Exp/output_notebook_eps50_caseID9_rep0.ipynb
# rep0_dataset891_eps50_caseID9
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 107095 bytes to results_Exp/output_notebook_eps50_caseID10_rep0.ipynb
# rep0_dataset891_eps50_caseID10
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 73710 bytes to results_Exp/output_notebook_eps50_caseID11_rep0.ipynb
# rep0_dataset891_eps50_caseID11
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 157992 bytes to results_Exp/output_notebook_eps50_caseID12_rep0.ipynb
# rep0_dataset891_eps50_caseID12
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 119600 bytes to results_Exp/output_notebook_eps50_caseID13_rep0.ipynb
# rep0_dataset891_eps50_caseID13
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 161143 bytes to results_Exp/output_notebook_eps50_caseID14_rep0.ipynb
# rep0_dataset891_eps50_caseID14
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 47921 bytes to results_Exp/output_notebook_eps100_caseID0_rep0.ipynb
# rep0_dataset891_eps100_caseID0
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 158725 bytes to results_Exp/output_notebook_eps100_caseID1_rep0.ipynb
# rep0_dataset891_eps100_caseID1
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 159168 bytes to results_Exp/output_notebook_eps100_caseID2_rep0.ipynb
# rep0_dataset891_eps100_caseID2
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 111043 bytes to results_Exp/output_notebook_eps100_caseID3_rep0.ipynb
# rep0_dataset891_eps100_caseID3
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 103714 bytes to results_Exp/output_notebook_eps100_caseID4_rep0.ipynb
# rep0_dataset891_eps100_caseID4
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 161301 bytes to results_Exp/output_notebook_eps100_caseID5_rep0.ipynb
# rep0_dataset891_eps100_caseID5
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 136571 bytes to results_Exp/output_notebook_eps100_caseID6_rep0.ipynb
# rep0_dataset891_eps100_caseID6
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 143597 bytes to results_Exp/output_notebook_eps100_caseID7_rep0.ipynb
# rep0_dataset891_eps100_caseID7
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 115826 bytes to results_Exp/output_notebook_eps100_caseID8_rep0.ipynb
# rep0_dataset891_eps100_caseID8
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 160615 bytes to results_Exp/output_notebook_eps100_caseID9_rep0.ipynb
# rep0_dataset891_eps100_caseID9
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 145887 bytes to results_Exp/output_notebook_eps100_caseID10_rep0.ipynb
# rep0_dataset891_eps100_caseID10
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 98320 bytes to results_Exp/output_notebook_eps100_caseID11_rep0.ipynb
# rep0_dataset891_eps100_caseID11
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 104746 bytes to results_Exp/output_notebook_eps100_caseID12_rep0.ipynb
# rep0_dataset891_eps100_caseID12
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 160326 bytes to results_Exp/output_notebook_eps100_caseID13_rep0.ipynb
# rep0_dataset891_eps100_caseID13
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 162709 bytes to results_Exp/output_notebook_eps100_caseID14_rep0.ipynb
# rep0_dataset891_eps100_caseID14
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 132869 bytes to results_Exp/output_notebook_eps0_caseID0_rep0.ipynb
# rep0_dataset891_eps0_caseID0
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 87188 bytes to results_Exp/output_notebook_eps0_caseID1_rep0.ipynb
# rep0_dataset891_eps0_caseID1
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 155024 bytes to results_Exp/output_notebook_eps0_caseID2_rep0.ipynb
# rep0_dataset891_eps0_caseID2
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 125343 bytes to results_Exp/output_notebook_eps0_caseID3_rep0.ipynb
# rep0_dataset891_eps0_caseID3
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 108755 bytes to results_Exp/output_notebook_eps0_caseID4_rep0.ipynb
# rep0_dataset891_eps0_caseID4
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 83652 bytes to results_Exp/output_notebook_eps0_caseID5_rep0.ipynb
# rep0_dataset891_eps0_caseID5
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 158294 bytes to results_Exp/output_notebook_eps0_caseID6_rep0.ipynb
# rep0_dataset891_eps0_caseID6
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 135145 bytes to results_Exp/output_notebook_eps0_caseID7_rep0.ipynb
# rep0_dataset891_eps0_caseID7
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 103405 bytes to results_Exp/output_notebook_eps0_caseID8_rep0.ipynb
# rep0_dataset891_eps0_caseID8
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 108812 bytes to results_Exp/output_notebook_eps0_caseID9_rep0.ipynb
# rep0_dataset891_eps0_caseID9
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 150557 bytes to results_Exp/output_notebook_eps0_caseID10_rep0.ipynb
# rep0_dataset891_eps0_caseID10
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 151197 bytes to results_Exp/output_notebook_eps0_caseID11_rep0.ipynb
# rep0_dataset891_eps0_caseID11
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 159278 bytes to results_Exp/output_notebook_eps0_caseID12_rep0.ipynb
# rep0_dataset891_eps0_caseID12
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 96356 bytes to results_Exp/output_notebook_eps0_caseID13_rep0.ipynb
# rep0_dataset891_eps0_caseID13
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 155410 bytes to results_Exp/output_notebook_eps0_caseID14_rep0.ipynb
# rep0_dataset891_eps0_caseID14
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 82953 bytes to results_Exp/output_notebook_eps1_caseID0_rep0.ipynb
# rep0_dataset2_eps1_caseID0
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 99623 bytes to results_Exp/output_notebook_eps1_caseID1_rep0.ipynb
# rep0_dataset2_eps1_caseID1
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 86994 bytes to results_Exp/output_notebook_eps1_caseID2_rep0.ipynb
# rep0_dataset2_eps1_caseID2
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 98689 bytes to results_Exp/output_notebook_eps1_caseID3_rep0.ipynb
# rep0_dataset2_eps1_caseID3
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# ...
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 17755 bytes to results_Exp/output_notebook_eps50_caseID13_rep4.ipynb
# rep4_dataset45_eps50_caseID13
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 20783 bytes to results_Exp/output_notebook_eps50_caseID14_rep4.ipynb
# rep4_dataset45_eps50_caseID14
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 25434 bytes to results_Exp/output_notebook_eps100_caseID0_rep4.ipynb
# rep4_dataset45_eps100_caseID0
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 26442 bytes to results_Exp/output_notebook_eps100_caseID1_rep4.ipynb
# rep4_dataset45_eps100_caseID1
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing