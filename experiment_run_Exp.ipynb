# %%
import os
import time

output_directory = "./results_Exp"
os.makedirs(output_directory, exist_ok=True)
notebook = "PP_steps_verification_Exp.ipynb"

# %%
dataset_id_list = ['891', '2', '697']

case_id_list = [str(i) for i in range(15)]

repeat = 5

# %%
for rep in range(repeat):
    os.environ['REPEAT'] = str(rep)
    for dataset_id in dataset_id_list:
        os.environ['DATASET_ID'] = dataset_id
        
        if os.environ['DATASET_ID'] == '891':
            epsilon_list = ['0.1', '1', '10', '100', '1000', '0']
            os.environ['NUMERICAL_COLUMNS'] = 'BMI, GenHlth, MentHlth, PhysHlth, Age, Education, Income'
        elif os.environ['DATASET_ID'] == '2':
            epsilon_list = ['0.1', '1', '10', '100', '1000', '0']
            os.environ['NUMERICAL_COLUMNS'] = 'age, fnlwgt, education-num, capital-gain, capital-loss, hours-per-week'
        elif os.environ['DATASET_ID'] == '697':
            epsilon_list = ['0.1', '1', '10', '100', '1000', '0']
            os.environ['NUMERICAL_COLUMNS'] = 'Previous qualification (grade), Admission grade, Unemployment rate, Inflation rate, GDP'
    
        for eps in epsilon_list:
            os.environ['EPSILON'] = eps
            for case_id in case_id_list:
                os.environ['CASE_ID'] = case_id
        
                output_file = os.path.join(output_directory, f"output_notebook_eps{eps}_caseID{case_id}_rep{rep}.ipynb")
                
                command = f"jupyter nbconvert --to notebook --execute {notebook} --output {output_file}"
                # command = f"jupyter nbconvert --to notebook --execute {notebook}"

                os.system(command)
                print(f'rep{rep}_dataset{dataset_id}_eps{eps}_caseID{case_id}')
# Out:
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 311673 bytes to results_Exp/output_notebook_eps0.1_caseID0_rep0.ipynb
# rep0_dataset891_eps0.1_caseID0
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 328422 bytes to results_Exp/output_notebook_eps0.1_caseID1_rep0.ipynb
# rep0_dataset891_eps0.1_caseID1
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 327501 bytes to results_Exp/output_notebook_eps0.1_caseID2_rep0.ipynb
# rep0_dataset891_eps0.1_caseID2
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 318236 bytes to results_Exp/output_notebook_eps0.1_caseID3_rep0.ipynb
# rep0_dataset891_eps0.1_caseID3
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 309210 bytes to results_Exp/output_notebook_eps0.1_caseID4_rep0.ipynb
# rep0_dataset891_eps0.1_caseID4
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 330892 bytes to results_Exp/output_notebook_eps0.1_caseID5_rep0.ipynb
# rep0_dataset891_eps0.1_caseID5
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 329833 bytes to results_Exp/output_notebook_eps0.1_caseID6_rep0.ipynb
# rep0_dataset891_eps0.1_caseID6
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 327309 bytes to results_Exp/output_notebook_eps0.1_caseID7_rep0.ipynb
# rep0_dataset891_eps0.1_caseID7
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 328354 bytes to results_Exp/output_notebook_eps0.1_caseID8_rep0.ipynb
# rep0_dataset891_eps0.1_caseID8
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 326958 bytes to results_Exp/output_notebook_eps0.1_caseID9_rep0.ipynb
# rep0_dataset891_eps0.1_caseID9
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 317215 bytes to results_Exp/output_notebook_eps0.1_caseID10_rep0.ipynb
# rep0_dataset891_eps0.1_caseID10
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 330208 bytes to results_Exp/output_notebook_eps0.1_caseID11_rep0.ipynb
# rep0_dataset891_eps0.1_caseID11
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 330505 bytes to results_Exp/output_notebook_eps0.1_caseID12_rep0.ipynb
# rep0_dataset891_eps0.1_caseID12
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 326387 bytes to results_Exp/output_notebook_eps0.1_caseID13_rep0.ipynb
# rep0_dataset891_eps0.1_caseID13
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 323614 bytes to results_Exp/output_notebook_eps0.1_caseID14_rep0.ipynb
# rep0_dataset891_eps0.1_caseID14
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 316346 bytes to results_Exp/output_notebook_eps1_caseID0_rep0.ipynb
# rep0_dataset891_eps1_caseID0
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 332437 bytes to results_Exp/output_notebook_eps1_caseID1_rep0.ipynb
# rep0_dataset891_eps1_caseID1
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 329910 bytes to results_Exp/output_notebook_eps1_caseID2_rep0.ipynb
# rep0_dataset891_eps1_caseID2
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 325639 bytes to results_Exp/output_notebook_eps1_caseID3_rep0.ipynb
# rep0_dataset891_eps1_caseID3
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 317411 bytes to results_Exp/output_notebook_eps1_caseID4_rep0.ipynb
# rep0_dataset891_eps1_caseID4
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 333301 bytes to results_Exp/output_notebook_eps1_caseID5_rep0.ipynb
# rep0_dataset891_eps1_caseID5
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 333686 bytes to results_Exp/output_notebook_eps1_caseID6_rep0.ipynb
# rep0_dataset891_eps1_caseID6
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 329555 bytes to results_Exp/output_notebook_eps1_caseID7_rep0.ipynb
# rep0_dataset891_eps1_caseID7
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 330765 bytes to results_Exp/output_notebook_eps1_caseID8_rep0.ipynb
# rep0_dataset891_eps1_caseID8
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 327758 bytes to results_Exp/output_notebook_eps1_caseID9_rep0.ipynb
# rep0_dataset891_eps1_caseID9
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 318016 bytes to results_Exp/output_notebook_eps1_caseID10_rep0.ipynb
# rep0_dataset891_eps1_caseID10
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 333585 bytes to results_Exp/output_notebook_eps1_caseID11_rep0.ipynb
# rep0_dataset891_eps1_caseID11
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 333879 bytes to results_Exp/output_notebook_eps1_caseID12_rep0.ipynb
# rep0_dataset891_eps1_caseID12
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 329443 bytes to results_Exp/output_notebook_eps1_caseID13_rep0.ipynb
# rep0_dataset891_eps1_caseID13
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 331493 bytes to results_Exp/output_notebook_eps1_caseID14_rep0.ipynb
# rep0_dataset891_eps1_caseID14
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 311850 bytes to results_Exp/output_notebook_eps10_caseID0_rep0.ipynb
# rep0_dataset891_eps10_caseID0
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 331484 bytes to results_Exp/output_notebook_eps10_caseID1_rep0.ipynb
# rep0_dataset891_eps10_caseID1
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 333936 bytes to results_Exp/output_notebook_eps10_caseID2_rep0.ipynb
# rep0_dataset891_eps10_caseID2
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 318564 bytes to results_Exp/output_notebook_eps10_caseID3_rep0.ipynb
# rep0_dataset891_eps10_caseID3
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 317577 bytes to results_Exp/output_notebook_eps10_caseID4_rep0.ipynb
# rep0_dataset891_eps10_caseID4
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 332017 bytes to results_Exp/output_notebook_eps10_caseID5_rep0.ipynb
# rep0_dataset891_eps10_caseID5
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 330630 bytes to results_Exp/output_notebook_eps10_caseID6_rep0.ipynb
# rep0_dataset891_eps10_caseID6
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 331483 bytes to results_Exp/output_notebook_eps10_caseID7_rep0.ipynb
# rep0_dataset891_eps10_caseID7
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 332538 bytes to results_Exp/output_notebook_eps10_caseID8_rep0.ipynb
# rep0_dataset891_eps10_caseID8
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 334515 bytes to results_Exp/output_notebook_eps10_caseID9_rep0.ipynb
# rep0_dataset891_eps10_caseID9
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 323160 bytes to results_Exp/output_notebook_eps10_caseID10_rep0.ipynb
# rep0_dataset891_eps10_caseID10
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 333748 bytes to results_Exp/output_notebook_eps10_caseID11_rep0.ipynb
# rep0_dataset891_eps10_caseID11
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 331471 bytes to results_Exp/output_notebook_eps10_caseID12_rep0.ipynb
# rep0_dataset891_eps10_caseID12
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 324944 bytes to results_Exp/output_notebook_eps10_caseID13_rep0.ipynb
# rep0_dataset891_eps10_caseID13
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 333744 bytes to results_Exp/output_notebook_eps10_caseID14_rep0.ipynb
# rep0_dataset891_eps10_caseID14
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 314105 bytes to results_Exp/output_notebook_eps100_caseID0_rep0.ipynb
# rep0_dataset891_eps100_caseID0
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 326817 bytes to results_Exp/output_notebook_eps100_caseID1_rep0.ipynb
# rep0_dataset891_eps100_caseID1
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 332490 bytes to results_Exp/output_notebook_eps100_caseID2_rep0.ipynb
# rep0_dataset891_eps100_caseID2
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 309889 bytes to results_Exp/output_notebook_eps100_caseID3_rep0.ipynb
# rep0_dataset891_eps100_caseID3
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 310019 bytes to results_Exp/output_notebook_eps100_caseID4_rep0.ipynb
# rep0_dataset891_eps100_caseID4
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 330896 bytes to results_Exp/output_notebook_eps100_caseID5_rep0.ipynb
# rep0_dataset891_eps100_caseID5
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 328868 bytes to results_Exp/output_notebook_eps100_caseID6_rep0.ipynb
# rep0_dataset891_eps100_caseID6
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 332771 bytes to results_Exp/output_notebook_eps100_caseID7_rep0.ipynb
# rep0_dataset891_eps100_caseID7
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 328363 bytes to results_Exp/output_notebook_eps100_caseID8_rep0.ipynb
# rep0_dataset891_eps100_caseID8
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 325993 bytes to results_Exp/output_notebook_eps100_caseID9_rep0.ipynb
# rep0_dataset891_eps100_caseID9
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 320107 bytes to results_Exp/output_notebook_eps100_caseID10_rep0.ipynb
# rep0_dataset891_eps100_caseID10
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 330536 bytes to results_Exp/output_notebook_eps100_caseID11_rep0.ipynb
# rep0_dataset891_eps100_caseID11
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 330991 bytes to results_Exp/output_notebook_eps100_caseID12_rep0.ipynb
# rep0_dataset891_eps100_caseID12
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 327358 bytes to results_Exp/output_notebook_eps100_caseID13_rep0.ipynb
# rep0_dataset891_eps100_caseID13
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 328920 bytes to results_Exp/output_notebook_eps100_caseID14_rep0.ipynb
# rep0_dataset891_eps100_caseID14
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 309122 bytes to results_Exp/output_notebook_eps1000_caseID0_rep0.ipynb
# rep0_dataset891_eps1000_caseID0
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 325213 bytes to results_Exp/output_notebook_eps1000_caseID1_rep0.ipynb
# rep0_dataset891_eps1000_caseID1
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 328474 bytes to results_Exp/output_notebook_eps1000_caseID2_rep0.ipynb
# rep0_dataset891_eps1000_caseID2
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 312772 bytes to results_Exp/output_notebook_eps1000_caseID3_rep0.ipynb
# rep0_dataset891_eps1000_caseID3
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 311783 bytes to results_Exp/output_notebook_eps1000_caseID4_rep0.ipynb
# rep0_dataset891_eps1000_caseID4
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 330411 bytes to results_Exp/output_notebook_eps1000_caseID5_rep0.ipynb
# rep0_dataset891_eps1000_caseID5
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 332080 bytes to results_Exp/output_notebook_eps1000_caseID6_rep0.ipynb
# rep0_dataset891_eps1000_caseID6
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 333575 bytes to results_Exp/output_notebook_eps1000_caseID7_rep0.ipynb
# rep0_dataset891_eps1000_caseID7
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 329645 bytes to results_Exp/output_notebook_eps1000_caseID8_rep0.ipynb
# rep0_dataset891_eps1000_caseID8
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 326803 bytes to results_Exp/output_notebook_eps1000_caseID9_rep0.ipynb
# rep0_dataset891_eps1000_caseID9
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 311904 bytes to results_Exp/output_notebook_eps1000_caseID10_rep0.ipynb
# rep0_dataset891_eps1000_caseID10
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 332782 bytes to results_Exp/output_notebook_eps1000_caseID11_rep0.ipynb
# rep0_dataset891_eps1000_caseID11
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 329861 bytes to results_Exp/output_notebook_eps1000_caseID12_rep0.ipynb
# rep0_dataset891_eps1000_caseID12
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 327513 bytes to results_Exp/output_notebook_eps1000_caseID13_rep0.ipynb
# rep0_dataset891_eps1000_caseID13
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 332460 bytes to results_Exp/output_notebook_eps1000_caseID14_rep0.ipynb
# rep0_dataset891_eps1000_caseID14
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 295930 bytes to results_Exp/output_notebook_eps0_caseID0_rep0.ipynb
# rep0_dataset891_eps0_caseID0
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 329231 bytes to results_Exp/output_notebook_eps0_caseID1_rep0.ipynb
# rep0_dataset891_eps0_caseID1
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 327538 bytes to results_Exp/output_notebook_eps0_caseID2_rep0.ipynb
# rep0_dataset891_eps0_caseID2
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 307960 bytes to results_Exp/output_notebook_eps0_caseID3_rep0.ipynb
# rep0_dataset891_eps0_caseID3
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 299084 bytes to results_Exp/output_notebook_eps0_caseID4_rep0.ipynb
# rep0_dataset891_eps0_caseID4
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 332021 bytes to results_Exp/output_notebook_eps0_caseID5_rep0.ipynb
# rep0_dataset891_eps0_caseID5
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 331437 bytes to results_Exp/output_notebook_eps0_caseID6_rep0.ipynb
# rep0_dataset891_eps0_caseID6
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 333898 bytes to results_Exp/output_notebook_eps0_caseID7_rep0.ipynb
# rep0_dataset891_eps0_caseID7
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 326433 bytes to results_Exp/output_notebook_eps0_caseID8_rep0.ipynb
# rep0_dataset891_eps0_caseID8
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 330338 bytes to results_Exp/output_notebook_eps0_caseID9_rep0.ipynb
# rep0_dataset891_eps0_caseID9
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 312961 bytes to results_Exp/output_notebook_eps0_caseID10_rep0.ipynb
# rep0_dataset891_eps0_caseID10
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 331336 bytes to results_Exp/output_notebook_eps0_caseID11_rep0.ipynb
# rep0_dataset891_eps0_caseID11
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 328739 bytes to results_Exp/output_notebook_eps0_caseID12_rep0.ipynb
# rep0_dataset891_eps0_caseID12
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 325991 bytes to results_Exp/output_notebook_eps0_caseID13_rep0.ipynb
# rep0_dataset891_eps0_caseID13
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 330371 bytes to results_Exp/output_notebook_eps0_caseID14_rep0.ipynb
# rep0_dataset891_eps0_caseID14
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 234585 bytes to results_Exp/output_notebook_eps0.1_caseID0_rep0.ipynb
# rep0_dataset2_eps0.1_caseID0
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 232200 bytes to results_Exp/output_notebook_eps0.1_caseID1_rep0.ipynb
# rep0_dataset2_eps0.1_caseID1
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 234405 bytes to results_Exp/output_notebook_eps0.1_caseID2_rep0.ipynb
# rep0_dataset2_eps0.1_caseID2
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 234620 bytes to results_Exp/output_notebook_eps0.1_caseID3_rep0.ipynb
# rep0_dataset2_eps0.1_caseID3
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# ...
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 70787 bytes to results_Exp/output_notebook_eps100_caseID13_rep4.ipynb
# rep4_dataset697_eps100_caseID13
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 69461 bytes to results_Exp/output_notebook_eps100_caseID14_rep4.ipynb
# rep4_dataset697_eps100_caseID14
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 70957 bytes to results_Exp/output_notebook_eps1000_caseID0_rep4.ipynb
# rep4_dataset697_eps1000_caseID0
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 71201 bytes to results_Exp/output_notebook_eps1000_caseID1_rep4.ipynb
# rep4_dataset697_eps1000_caseID1
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 69646 bytes to results_Exp/output_notebook_eps1000_caseID2_rep4.ipynb
# rep4_dataset697_eps1000_caseID2
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 71071 bytes to results_Exp/output_notebook_eps1000_caseID3_rep4.ipynb
# rep4_dataset697_eps1000_caseID3
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 71209 bytes to results_Exp/output_notebook_eps1000_caseID4_rep4.ipynb
# rep4_dataset697_eps1000_caseID4
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 70054 bytes to results_Exp/output_notebook_eps1000_caseID5_rep4.ipynb
# rep4_dataset697_eps1000_caseID5
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 71164 bytes to results_Exp/output_notebook_eps1000_caseID6_rep4.ipynb
# rep4_dataset697_eps1000_caseID6
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 69923 bytes to results_Exp/output_notebook_eps1000_caseID7_rep4.ipynb
# rep4_dataset697_eps1000_caseID7
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 70983 bytes to results_Exp/output_notebook_eps1000_caseID8_rep4.ipynb
# rep4_dataset697_eps1000_caseID8
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 69744 bytes to results_Exp/output_notebook_eps1000_caseID9_rep4.ipynb
# rep4_dataset697_eps1000_caseID9
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 70854 bytes to results_Exp/output_notebook_eps1000_caseID10_rep4.ipynb
# rep4_dataset697_eps1000_caseID10
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 69699 bytes to results_Exp/output_notebook_eps1000_caseID11_rep4.ipynb
# rep4_dataset697_eps1000_caseID11
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 69837 bytes to results_Exp/output_notebook_eps1000_caseID12_rep4.ipynb
# rep4_dataset697_eps1000_caseID12
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 70787 bytes to results_Exp/output_notebook_eps1000_caseID13_rep4.ipynb
# rep4_dataset697_eps1000_caseID13
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 69684 bytes to results_Exp/output_notebook_eps1000_caseID14_rep4.ipynb
# rep4_dataset697_eps1000_caseID14
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 70788 bytes to results_Exp/output_notebook_eps0_caseID0_rep4.ipynb
# rep4_dataset697_eps0_caseID0
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 71036 bytes to results_Exp/output_notebook_eps0_caseID1_rep4.ipynb
# rep4_dataset697_eps0_caseID1
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 69960 bytes to results_Exp/output_notebook_eps0_caseID2_rep4.ipynb
# rep4_dataset697_eps0_caseID2
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 70750 bytes to results_Exp/output_notebook_eps0_caseID3_rep4.ipynb
# rep4_dataset697_eps0_caseID3
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 70729 bytes to results_Exp/output_notebook_eps0_caseID4_rep4.ipynb
# rep4_dataset697_eps0_caseID4
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 69896 bytes to results_Exp/output_notebook_eps0_caseID5_rep4.ipynb
# rep4_dataset697_eps0_caseID5
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 70366 bytes to results_Exp/output_notebook_eps0_caseID6_rep4.ipynb
# rep4_dataset697_eps0_caseID6
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 69449 bytes to results_Exp/output_notebook_eps0_caseID7_rep4.ipynb
# rep4_dataset697_eps0_caseID7
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 70818 bytes to results_Exp/output_notebook_eps0_caseID8_rep4.ipynb
# rep4_dataset697_eps0_caseID8
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 69743 bytes to results_Exp/output_notebook_eps0_caseID9_rep4.ipynb
# rep4_dataset697_eps0_caseID9
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 70374 bytes to results_Exp/output_notebook_eps0_caseID10_rep4.ipynb
# rep4_dataset697_eps0_caseID10
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 69698 bytes to results_Exp/output_notebook_eps0_caseID11_rep4.ipynb
# rep4_dataset697_eps0_caseID11
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 69834 bytes to results_Exp/output_notebook_eps0_caseID12_rep4.ipynb
# rep4_dataset697_eps0_caseID12
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 70307 bytes to results_Exp/output_notebook_eps0_caseID13_rep4.ipynb
# rep4_dataset697_eps0_caseID13
# [NbConvertApp] Converting notebook PP_steps_verification_Exp.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# rep4_dataset697_eps0_caseID14
# [NbConvertApp] Writing 69301 bytes to results_Exp/output_notebook_eps0_caseID14_rep4.ipynb
